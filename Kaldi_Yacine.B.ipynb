# %% [markdown]
# <a href="https://colab.research.google.com/github/yacinebaroudi/Kaldi/blob/main/Kaldi_Yacine.B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install -y g++ automake autoconf libtool subversion
# !apt-get install -y zlib1g-dev libatlas3-base sox libtool-bin
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# autoconf is already the newest version (2.69-11.1).
# autoconf set to manually installed.
# automake is already the newest version (1:1.16.1-4ubuntu6).
# automake set to manually installed.
# g++ is already the newest version (4:9.3.0-1ubuntu2).
# g++ set to manually installed.
# The following additional packages will be installed:
#   libapr1 libaprutil1 libserf-1-1 libsvn1 libutf8proc2
# Suggested packages:
#   libtool-doc gcj-jdk db5.3-util libapache2-mod-svn subversion-tools
# The following NEW packages will be installed:
#   libapr1 libaprutil1 libserf-1-1 libsvn1 libtool libutf8proc2 subversion
# 0 upgraded, 7 newly installed, 0 to remove and 15 not upgraded.
# Need to get 2,516 kB of archives.
# After this operation, 11.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/main amd64 libapr1 amd64 1.6.5-1ubuntu1 [91.4 kB]
# ...

# %%
# !git clone https://github.com/kaldi-asr/kaldi.git
# Out:
# Cloning into 'kaldi'...
# remote: Enumerating objects: 115186, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 115186 (delta 7), reused 19 (delta 7), pack-reused 115164
# Receiving objects: 100% (115186/115186), 121.92 MiB | 32.93 MiB/s, done.
# Resolving deltas: 100% (88774/88774), done.

# %%
# %cd kaldi/src
# !./configure --shared --mathlib=OPENBLAS
# Out:
# [Errno 2] No such file or directory: 'kaldi/src'
# /content/kaldi/src
# Configuring KALDI to use OPENBLAS.
# Checking compiler c++ ...
# Checking OpenFst library in  ...
# ***configure failed: Could not find file /include/fst/fst.h:
#   you may not have installed OpenFst. See ../tools/INSTALL ***

# %%
# %cd /content/kaldi/tools
# Out:
# /content/kaldi/tools

# %%
# !ls
# Out:
# ATLAS_headers  extras		       install_portaudio.sh  Makefile
# CLAPACK        INSTALL		       install_speex.sh
# config	       install_pfile_utils.sh  install_srilm.sh

# %%
# !./install_openfst.sh
# Out:
# /bin/bash: ./install_openfst.sh: No such file or directory

# %%
# !./configure --enable-static --enable-shared --enable-far --enable-ngram-fsts --enable-lookahead-fsts --prefix=/usr/local
# !make -j4
# !make install
# Out:
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# checking for a thread-safe mkdir -p... /usr/bin/mkdir -p
# checking for gawk... no
# checking for mawk... mawk
# checking whether make sets $(MAKE)... yes
# checking whether make supports nested variables... yes
# checking whether make supports the include directive... yes (GNU style)
# checking for gcc... gcc
# checking whether the C compiler works... yes
# checking for C compiler default output file name... a.out
# checking for suffix of executables...
# checking whether we are cross compiling... no
# checking for suffix of object files... o
# checking whether we are using the GNU C compiler... yes
# checking whether gcc accepts -g... yes
# checking for gcc option to accept ISO C89... none needed
# checking whether gcc understands -c and -o together... yes
# checking dependency style of gcc... gcc3
# checking for ar... ar
# checking the archiver (ar) interface... ar
# ...
